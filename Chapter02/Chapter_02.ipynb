# %% [markdown]
# # Chapter 2: Getting Started with Prophet

# %% [markdown]
# ## Building a simple model in Prophet

# %%
import pandas as pd
import matplotlib.pyplot as plt
from prophet import Prophet

# %%
df = pd.read_csv('../data/co2-ppm-daily_csv.csv')
df['date'] = pd.to_datetime(df['date'])
df.columns = ['ds', 'y']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(pd.to_datetime(df['ds']), df['y'], s=1, c='#0072B2')
plt.xlabel('Date')
plt.ylabel(r'CO$_2$ Fraction in Dry Air')
plt.show()

# %%
model = Prophet()
model.fit(df)
# Out:
# 11:02:56 - cmdstanpy - INFO - Chain [1] start processing
# 11:03:16 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = model.make_future_dataframe(periods=365 * 10)
forecast = model.predict(future)

# %%
fig = model.plot(forecast, xlabel='Date', ylabel=r'CO$_2$ PPM')
plt.title('Daily Carbon Dioxide Levels Measured at Mauna Loa')
plt.show()

# %% [markdown]
# ## Interpreting the forecast DataFrame

# %%
forecast.head(3).T
# Out:
#                                               0                    1  \
# ds                          1958-03-30 00:00:00  1958-03-31 00:00:00
# trend                                 314.87681           314.879212
# yhat_lower                           316.026642           316.079937
# yhat_upper                           317.726869           317.789381
# trend_lower                           314.87681           314.879212
# trend_upper                           314.87681           314.879212
# additive_terms                         1.985679             2.015663
# additive_terms_lower                   1.985679             2.015663
# additive_terms_upper                   1.985679             2.015663
# weekly                                 0.003257            -0.010815
# weekly_lower                           0.003257            -0.010815
# weekly_upper                           0.003257            -0.010815
# yearly                                 1.982422             2.026479
# yearly_lower                           1.982422             2.026479
# yearly_upper                           1.982422             2.026479
# multiplicative_terms                        0.0                  0.0
# multiplicative_terms_lower                  0.0                  0.0
# multiplicative_terms_upper                  0.0                  0.0
# yhat                                  316.86249           316.894875
#
#                                               2
# ds                          1958-04-02 00:00:00
# trend                                314.884015
# yhat_lower                           316.153113
# yhat_upper                           317.876506
# trend_lower                          314.884015
# trend_upper                          314.884015
# additive_terms                         2.118861
# additive_terms_lower                   2.118861
# additive_terms_upper                   2.118861
# weekly                                 0.003454
# weekly_lower                           0.003454
# weekly_upper                           0.003454
# yearly                                 2.115407
# yearly_lower                           2.115407
# yearly_upper                           2.115407
# multiplicative_terms                        0.0
# multiplicative_terms_lower                  0.0
# multiplicative_terms_upper                  0.0
# yhat                                 317.002876

# %% [markdown]
# ## Understanding components plots

# %%
fig2 = model.plot_components(forecast)
plt.show()
